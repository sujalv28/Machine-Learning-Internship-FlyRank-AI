# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sujalv28/Machine-Learning-Internship-FlyRank-AI/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# #### 1. Task/Type : Scoring or Regression
# #### 2. I am doing this because my goal isn't just to categorize pages but to assign a priority score to each one. This score will directly helps to identify which pages need the most urgent attention, making the data actually actionable for the content strategy.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# #### I am using a proxy label to represent "Optimization Opportunity". I am defining this by measuring the gap between a page's current engagement ("clicks_90d") and the performance I would expect to see, given that page's visibility ("impressions_90d") and "position_tier". If a page has high visibility but low engagement compared to other pages, I am flagging it as a high-priority opportunity page.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# #### I am focusing on precision at Top 20. A good result is defined by a high precision score, mwaning that when I provide a ranked list of the top 20 pages for optimization, a significant portion of those pages demonstrate improved engagement metrics following human review and action. this metric direclty tracks my ability to effectively prioritize work for the content team, ensuring their time is focused on the most impactful opportunities.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# #### I am analysing the data at the content-item level, where each row represents one unique "content_id".

# %%
import pandas as pd
data = pd.read_csv('data/content_refresh_anonymized.csv')
data_slice = data[['content_id', 'impressions_90d', 'clicks_90d', 'avg_position', 'word_count']]
print(data_slice.head())
# Out:
#              content_id  impressions_90d  clicks_90d  avg_position  word_count
# 0  content_304f48230142             3803          29          10.6      3221.0
# 1  content_a1fb4e703a9e            15320           7          20.3      2481.0
# 2  content_9aa793d4d895            12581          11          36.5      3515.0
# 3  content_331d6c4de07b            11751          58           6.2         NaN
# 4  content_d99b7a2d90ca            19140          24          44.0      2803.0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# #### I have determined that a fixed rule, such as a static threshold for low clicks, is too rigid for this problem. A static rule fails to account for the necessary content of each page, such as its specific position or search content. By employing as ML model, I can capture the complex, non-linear relationships between the variables like "avg_position" and engagement across various content types. This approach allows for the creation of dynamic, personalized threshold for every page, providing level of refined decision-support that a manual rule-set cannot achieve.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
