# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sujalv28/Machine-Learning-Internship-FlyRank-AI/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# My lane is "Ranking Signal Analysis"
# This lane is ideal for building a foundational understanding of the dataset. Instead of jumping straight into acomplex model, I will be focusing more on uncovering which signals actually correlate with better performance.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# My work will help to determine whihc pages are under-resourced or neglected relative to their potential, so resources can be priortized effectively.
# A contect editor or a SEO manager.
# Based on my analysis, they will priortize a specific list of pages for manual review, re-optimisation, or expansion.
# If i flag a page that is actually performing perfectly fine, the editor wastes time reviewing it. And if I miss a high-potential page, the business loses out on traffic that could have been captured wiht a simple update.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
data = pd.read_csv('data/content_refresh_anonymized.csv')
data.head(5)
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
import pandas as pd
data = pd.read_csv('data/your_dataset_name.csv') # Replace with your actual file path
# Calculate these 3 numbers:
# 1. Total number of pages in the dataset
# 2. Average impressions per page
# 3. Correlation between 'word_count' and 'impressions'
print(f"Total pages: {len(data)}")
print(f"Avg impressions: {data['impressions'].mean():.2f}")
print(f"Correlation (word_count vs impressions): {data['word_count'].corr(data['impressions']):.2f}")
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1507/1601078512.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 data = pd.read_csv('data/your_dataset_name.csv') # Replace with your actual file path
#       3 # Calculate these 3 numbers:
#       4 # 1. Total number of pages in the dataset
#       5 # 2. Average impressions per page
#
# ...

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
