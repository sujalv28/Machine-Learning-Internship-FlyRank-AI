# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sujalv28/Machine-Learning-Internship-FlyRank-AI/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# #### 1. My lane is "Ranking Signal Analysis"
# #### 2. This lane is ideal for building a foundational understanding of the dataset. Instead of jumping straight into acomplex model, I will be focusing more on uncovering which signals actually correlate with better performance.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# #### 1. Decision : My work will help to determine whihc pages are under-resourced or neglected relative to their potential, so resources can be priortized effectively.
# #### 2. A contect editor or a SEO manager acts on it.
# #### 3. Action : Based on my analysis, they will priortize a specific list of pages for manual review, re-optimisation, or expansion.
# #### 4. Cost of a Wrong Call : If I flag a page that is actually performing perfectly fine, the editor wastes time reviewing it. And if I miss a high-potential page, the business loses out on traffic that could have been captured wiht a simple update.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
data = pd.read_csv('data/content_refresh_anonymized.csv')
print(data.columns)
total_pages = len(data)
avg_impressions = data['impressions_90d'].mean()
correlation = data['word_count'].corr(data['impressions_90d'])
print(f"Total pages: {total_pages}")
print(f"Avg impressions: {avg_impressions:.2f}")
print(f"Correlation (Word Count vs Impressions): {correlation:.2f}")
# Out:
# Index(['content_id', 'client_id', 'search_volume', 'competition',
#        'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count',
#        'char_count', 'provider_used', 'model_used', 'impressions_90d',
#        'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d',
#        'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d',
#        'days_with_impressions', 'days_with_sessions', 'impressions_last_30d',
#        'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d',
#        'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier',
#        'age_tier_order', 'days_since_last_update', 'freshness_tier',
#        'word_count_tier', 'char_count_tier', 'ctr', 'avg_position',
#        'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier',
#        'position_tier', 'trend_direction', 'trend_pct'],
#       dtype='object')
# Total pages: 30000
# Avg impressions: 5200.37
# Correlation (Word Count vs Impressions): 0.16

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# #### 1. I can claim that I observed the pages with higher word count tend to show a positive correlation with increased impressions in the dataset
# #### 2. I cannot claim that if I add 500 words to every pages, our traffic will double
# #### 3. Decision Support Only : My analysis will provide a ranked list of pages for editors to review on observed signals, helping them priortize their work more effectively

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
